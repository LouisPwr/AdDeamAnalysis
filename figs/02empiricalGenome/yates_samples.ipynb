# %%
import pandas as pd

# %%
# Creating the DataFrame using a dictionary
data = {
    "sampleSource": [
        "Gorilla", "Gorilla", "Gorilla", "Gorilla", "Gorilla", "Gorilla", "Gorilla",
        "Chimpanzee", "Chimpanzee", "Chimpanzee",
        "Neanderthal", "Neanderthal", "Neanderthal", "Neanderthal",
        "Modern human", "Modern human", "Modern human", "Modern human", "Modern human", 
        "Modern human", "Modern human", "Modern human", "Modern human", "Modern human", 
        "Modern human", "Modern human", "Modern human","Modern human"
    ],
    "species": [
        "Gorilla beringei beringei", "Gorilla beringei beringei", "Gorilla beringei grauer",
        "Gorilla gorilla gorilla", "Gorilla gorilla gorilla", "Gorilla gorilla gorilla", "Gorilla gorilla gorilla",
        "Pan troglodytes schweinfurthi", "Pan troglodytes ellioti", "Pan troglodytes ellioti",
        "Homo (Neanderthal)", "Homo (Neanderthal)", "Homo (Neanderthal)", "Homo (Neanderthal)",
        "Homo sapiens (modern human, pre-agricultural)", "Homo sapiens (modern human, pre-agricultural)",
        "Homo sapiens (modern human, pre-agricultural)", "Homo sapiens (modern human, pre-agricultural)",
        "Homo sapiens (modern human, pre-agricultural)", "Homo sapiens (modern human, pre-agricultural)",
        "Homo sapiens (modern human, pre-agricultural)", "Homo sapiens (modern human, pre-agricultural)",
        "Homo sapiens (modern human, pre-antibiotic)", "Homo sapiens (modern human, pre-antibiotic)",
        "Homo sapiens (modern human, pre-antibiotic)", "Homo sapiens (modern human, pre-antibiotic)",
        "Homo sapiens (modern human, present day)", "Homo sapiens (modern human, present day)"
    ],
    "origin": [
        "Mount Sabyinyo", "Mount Mikena", "Bitule", 
        "Abang Mbang", "Djaposten", "Ebolowa", "Mount Mikena",
        "Kibale National Forest", "Abang Mbang", "Ebolwa",
        "Pesturina Cave", "Funare", "de Nadale", "Troisième caveme of Gayet",
        "Oakhunst", "Taforalt", "Mota", "Dolní Vestorice", "El Miron", 
        "Rigney", "El Collado", "Grasse Ofnet Höhle", "Essaouira (Mogador)",
        "Polyoak", "Lisbon", "Basque country (modern day region af)", "Valencia", "Jaen"
    ],
    "code": [
        "DR Congo", "DR Congo", "DR Congo", 
        "Cameroon", "Cameroon", "Cameroon", "DR Congo",
        "Uganda", "Cameroon", "Cameroon",
        "Serbia", "Italy", "Italy", "Belgium",
        "South Africa", "Maracco", "Ethiopia", "Czech Republic", "Spain", 
        "France", "Spain", "Germany", "Maracco",
        "South Africa", "Portugal", "Spain", "Spain", "Spain"
    ],
    "totalAssessed": [
        11, 11, 11, 
        2, 2, 2, 1, 
        7, 2, 2, 
        1, 1, 2, 2, 
        4, 3, 1, 2, 1, 
        1, 3, 1, 5, 
        5, 3, 1, 8, 10
    ],
    "passed": [
        6, 6, 0, 
        2, 2, 2, 1, 
        7, 2, 2, 
        1, 1, 2, 2, 
        4, 3, 1, 2, 1, 
        1, 3, 1, 5, 
        5, 3, 1, 8, 10
    ],
    "samples": [
        "MT5001;MT5002;MT5003;MT5004;MT5005;MT5006", 
        "MTM001;MTM004;MTM005;MTMOOS;MTM008;MTM009", 
        "FDM001", 
        "ABM007;ABM008", 
        "DJA006;DJA007", 
        "EB0008;EB0009", 
        "MTM010", 
        "KNP001;KNP003;KNP004;KNP005;KNP006;KNP007;KNP009", 
        "ABM007;ABM008", 
        "EB0008;EB0009", 
        "PES001", 
        "FUM002", 
        "GOY005;GOY006", 
        "GOY005;GOY006", 
        "OAK001;OAK002;OAK003;OAK004;OAKOOS", 
        "TAF008;TAF017;TAF018", 
        "MOA001", 
        "PLV001", 
        "EMN001", 
        "RIG001", 
        "EC0002;EC0004;EC0010", 
        "OFN001", 
        "ESA003;ESA004;ESA006;ESA007;ESA008", 
        "PYK001;ΡYK002;PYK003;PYK004;PYK005.", 
        "LIS001;LIS002;LIS003", 
        "BSQ001", 
        "VL0001;M.0002;V.0003;VLC004;VLC005;VLC008;VL0009;V.0010", 
        "JAEDOG;JAE007;JAE008;JAE009;JAE010;JAE0"
    ],
}

# %%
# Convert the data dictionary into a pandas DataFrame
df = pd.DataFrame(data)

df.to_csv("yates_samples_info.tsv", sep="\t", index=False)
# Display the DataFrame
print(df)
# Out:
#     sampleSource                                        species  \
# 0        Gorilla                      Gorilla beringei beringei
# 1        Gorilla                      Gorilla beringei beringei
# 2        Gorilla                        Gorilla beringei grauer
# 3        Gorilla                        Gorilla gorilla gorilla
# 4        Gorilla                        Gorilla gorilla gorilla
# 5        Gorilla                        Gorilla gorilla gorilla
# 6        Gorilla                        Gorilla gorilla gorilla
# 7     Chimpanzee                  Pan troglodytes schweinfurthi
# 8     Chimpanzee                        Pan troglodytes ellioti
# 9     Chimpanzee                        Pan troglodytes ellioti
# 10   Neanderthal                             Homo (Neanderthal)
# 11   Neanderthal                             Homo (Neanderthal)
# 12   Neanderthal                             Homo (Neanderthal)
# 13   Neanderthal                             Homo (Neanderthal)
# ...
