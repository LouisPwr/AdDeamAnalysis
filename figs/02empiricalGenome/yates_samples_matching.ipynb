# %%
import pandas as pd
import numpy as np

# %%
def match_and_merge_tsvs(tsv1_path, tsv2_path, output_path='matched_tsv.tsv'):
    # Read the TSV files into pandas DataFrames
    tsv1 = pd.read_csv(tsv1_path, sep='\t')
    tsv2 = pd.read_csv(tsv2_path, sep='\t')

    # Create new columns in tsv1 for the period, sample source, and UDG treated
    tsv1['period'] = None
    tsv1['sampleSource'] = None
    tsv1['code'] = None
    
    # Add the 'UDG treated' column based on the presence of "SG1.1" in the 'SampleName'
    tsv1['UDG treated'] = np.where(tsv1['SampleName'].str.contains('SG1.1', regex=False), 'yes', 'no')

    # Iterate over rows of tsv2 to extract samples and their associated period and sample source
    for _, row in tsv2.iterrows():
        samples = row['samples'].split(';')
        period = row['period']
        code = row['code']
        sample_source = row['sampleSource']
        
        # Iterate over the samples and check if any are substrings in the 'SampleName' column of tsv1
        for sample in samples:
            # Find rows in tsv1 where the sample is a substring of 'SampleName'
            matches = tsv1['SampleName'].str.contains(sample, regex=False)
            # Update 'period' and 'sampleSource' for matched rows
            tsv1.loc[matches, 'period'] = period
            tsv1.loc[matches, 'code'] = code
            tsv1.loc[matches, 'sampleSource'] = sample_source

    # Identify the primary cluster for each sample based on the cluster columns
    cluster_columns = ['Cluster1', 'Cluster2', 'Cluster3', 'Cluster4']
    tsv1['PrimaryCluster'] = tsv1[cluster_columns].idxmax(axis=1)

    # Sort by 'PrimaryCluster' and then by 'period' alphabetically within each cluster
    tsv1 = tsv1.sort_values(by=['PrimaryCluster', 'period', 'code'])

    # Write the updated tsv1 to a new TSV file
    tsv1.to_csv(output_path, sep='\t', index=False)
    print(f"Matched TSV saved to: {output_path}")

    return tsv1

# Example usage
# match_and_merge_tsvs('path_to_tsv1.tsv', 'path_to_tsv2.tsv', 'output_tsv.tsv')

# %%
# Example usage
match_and_merge_tsvs('/home/metagnm_asm/project2/bam2profDevs/bam2prof_production/yates_bam5_v2_classic_plots/GMM/k4/cluster_report_k4.tsv', 
                     '/home/metagnm_asm/project2/submission/figs/02empiricalGenome/yates_samples.tsv', 
                     'output_tsv.tsv')
# Out:
# Matched TSV saved to: output_tsv.tsv
#     SampleID                                     SampleName  AlignedFrags  \
# 9         10  DJA002.A0102.SG1.1_sorted_md_classic_n1538844       1538844
# 2          3   EBO003.A0102.SG1.1_sorted_md_classic_n402309        402309
# 0          1           OME007.A0101_sorted_md_classic_n2852          2852
# 7          8    OME005.A0102.SG1.1_sorted_md_classic_n71298         71298
# 11        12    OME003.A0102.SG1.1_sorted_md_classic_n81895         81895
# 13        14    OME002.A0102.SG1.1_sorted_md_classic_n54668         54668
# 3          4   OAK002.A0102.SG1.1_sorted_md_classic_n117874        117874
# 6          7   OAK005.A0102.SG1.1_sorted_md_classic_n270210        270210
# 4          5   TAF008.B0102.SG1.1_sorted_md_classic_n245414        245414
# 8          9    ECO002.B0102.SG1.1_sorted_md_classic_n99145         99145
# 10        11   ECO004.B0103.SG1.1_sorted_md_classic_n149685        149685
# 1          2     FUM002.A0103.SG1.1_sorted_md_classic_n8272          8272
# 12        13    PES001.B0103.SG1.1_sorted_md_classic_n34803         34803
# 5          6   EMN001.A0102.SG1.1_sorted_md_classic_n118127        118127
# 16        17          DJA006.A0101_sorted_md_classic_n23929         23929
# 19        20  DJA007.A0101.171215_sorted_md_classic_n169947        169947
# 20        21   DJA006.A0101.171215_sorted_md_classic_n65455         65455
# 22        23         DJA002.A0101_sorted_md_classic_n247246        247246
# 25        26          DJA007.A0101_sorted_md_classic_n85298         85298
# 15        16   EBO008.A0101.171215_sorted_md_classic_n37834         37834
# 17        18         EBO003.A0101_sorted_md_classic_n102068        102068
# 23        24          EBO008.A0101_sorted_md_classic_n17825         17825
# 24        25          EBO001.A0101_sorted_md_classic_n17988         17988
# 26        27           EBO009.A0101_sorted_md_classic_n8279          8279
# 27        28    EBO009.A0101.171215_sorted_md_classic_n8577          8577
# 14        15           OME005.A0101_sorted_md_classic_n5044          5044
# 18        19          OME002.A0101_sorted_md_classic_n10169         10169
# 21        22          OME003.A0101_sorted_md_classic_n16862         16862
# 32        33          OAK004.A0101_sorted_md_classic_n29027         29027
# 35        36         OAK005.A0101_sorted_md_classic_n159246        159246
# 38        39         OAK003.A0101_sorted_md_classic_n195287        195287
# 29        30          TAF018.B0101_sorted_md_classic_n10561         10561
# 31        32          TAF008.B0101_sorted_md_classic_n44039         44039
# 39        40           TAF018.A0101_sorted_md_classic_n1711          1711
# 40        41           TAF017.A0101_sorted_md_classic_n8239          8239
# 28        29           FUM001.A0101_sorted_md_classic_n5662          5662
# 33        34           FUM003.A0101_sorted_md_classic_n1732          1732
# 36        37           FUM002.A0101_sorted_md_classic_n4157          4157
# 37        38           PES001.B0101_sorted_md_classic_n7119          7119
# 34        35          EMN001.A0101_sorted_md_classic_n13653         13653
# 30        31            ECO006.B0101_sorted_md_classic_n796           796
# 48        49          OAK001.A0101_sorted_md_classic_n19567         19567
# 41        42    TAF017.C0101.171215_sorted_md_classic_n4682          4682
# 45        46           TAF017.C0101_sorted_md_classic_n4703          4703
# 42        43          ECO002.B0101_sorted_md_classic_n24381         24381
# 43        44          ECO004.C0101_sorted_md_classic_n20688         20688
# 44        45          ECO004.B0101_sorted_md_classic_n35193         35193
# 46        47          ECO010.B0101_sorted_md_classic_n17221         17221
# 47        48          ECO002.C0101_sorted_md_classic_n39924         39924
#
#     Cluster1  Cluster2  Cluster3  Cluster4  ClusterCenterDist  \
# 9        1.0    0.0000    0.0000    0.0000             0.3919
# 2        1.0    0.0000    0.0000    0.0000             0.4985
# 0     20th-21st century  Howler Monkey   OEM          no       Cluster1
# 7     20th-21st century  Howler Monkey   OEM         yes       Cluster1
# 11    20th-21st century  Howler Monkey   OEM         yes       Cluster1
# 13    20th-21st century  Howler Monkey   OEM         yes       Cluster1
# 3       Later Stone Age   Modern human   OAK         yes       Cluster1
# 6       Later Stone Age   Modern human   OAK         yes       Cluster1
# 4       Later Stone Age   Modern human   TAF         yes       Cluster1
# 8            Mesolithic   Modern human   ECO         yes       Cluster1
# 10           Mesolithic   Modern human   ECO         yes       Cluster1
# 1   Middle Palaeolithic    Neanderthal   FUM         yes       Cluster1
# 12  Middle Palaeolithic    Neanderthal   PES         yes       Cluster1
# 5    Upper Palaeolithic   Modern human   EMN         yes       Cluster1
# 16         20th century     Chimpanzee   DJA          no       Cluster2
# 19         20th century     Chimpanzee   DJA          no       Cluster2
# 20         20th century     Chimpanzee   DJA          no       Cluster2
# 22         20th century        Gorilla   DJA          no       Cluster2
# 25         20th century     Chimpanzee   DJA          no       Cluster2
# 15         20th century     Chimpanzee   EBO          no       Cluster2
# 17         20th century        Gorilla   EBO          no       Cluster2
# 23         20th century     Chimpanzee   EBO          no       Cluster2
# 24         20th century        Gorilla   EBO          no       Cluster2
# 26         20th century     Chimpanzee   EBO          no       Cluster2
# 27         20th century     Chimpanzee   EBO          no       Cluster2
# 14    20th-21st century  Howler Monkey   OEM          no       Cluster2
# 18    20th-21st century  Howler Monkey   OEM          no       Cluster2
# 21    20th-21st century  Howler Monkey   OEM          no       Cluster2
# 32      Later Stone Age   Modern human   OAK          no       Cluster3
# 35      Later Stone Age   Modern human   OAK          no       Cluster3
# 38      Later Stone Age   Modern human   OAK          no       Cluster3
# 29      Later Stone Age   Modern human   TAF          no       Cluster3
# 31      Later Stone Age   Modern human   TAF          no       Cluster3
# 39      Later Stone Age   Modern human   TAF          no       Cluster3
# 40      Later Stone Age   Modern human   TAF          no       Cluster3
# 28  Middle Palaeolithic    Neanderthal   FUM          no       Cluster3
# 33  Middle Palaeolithic    Neanderthal   FUM          no       Cluster3
# 36  Middle Palaeolithic    Neanderthal   FUM          no       Cluster3
# 37  Middle Palaeolithic    Neanderthal   PES          no       Cluster3
# 34   Upper Palaeolithic   Modern human   EMN          no       Cluster3
# 30                 None           None  None          no       Cluster3
# 48      Later Stone Age   Modern human   OAK          no       Cluster4
# 41      Later Stone Age   Modern human   TAF          no       Cluster4
# 45      Later Stone Age   Modern human   TAF          no       Cluster4
# 42           Mesolithic   Modern human   ECO          no       Cluster4
# 43           Mesolithic   Modern human   ECO          no       Cluster4
# 44           Mesolithic   Modern human   ECO          no       Cluster4
# 46           Mesolithic   Modern human   ECO          no       Cluster4
# 47           Mesolithic   Modern human   ECO          no       Cluster4
